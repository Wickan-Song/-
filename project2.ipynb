# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv(r'C:\Users\songx\Desktop\学校\深度学习12个项目实践\深度学习12个项目实践\数据集\titanic.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#查看缺失的数据：Nan
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

# 确保 data['Survived'] 不是空的
if not data.empty and 'Survived' in data.columns:
    # 修正 explode 参数
    explode_values = [0] * data['Survived'].nunique()
    
    data['Survived'].value_counts().plot.pie(
        explode=explode_values, autopct='%1.1f%%', ax=ax[0], shadow=True,
        colors=["#1f77b4", "#ff7f0e"] 
    )
    ax[0].set_title('Survived')
    ax[0].set_ylabel('')

    
    sns.countplot(x='Survived', data=data, ax=ax[1], palette=["#1f77b4", "#ff7f0e"])
   

    plt.show()
else:
    print("数据集为空或缺少 'Survived' 列")

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
#性别与生存概率的关系
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot(x='Sex', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
#年龄与获救
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_c30bf_row0_col0, #T_c30bf_row1_col1, #T_c30bf_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_c30bf_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_c30bf_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_c30bf_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_c30bf_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_c30bf_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_c30bf_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_c30bf_row3_col0, #T_c30bf_row3_col1, #T_c30bf_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c30bf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_c30bf_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c30bf_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %%
#船舱等级与生存概率关系
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#00429d', '#4771b2', '#9cc9e0'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot(x='Pclass', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
#对于空值进行处理
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_9f7d5_row0_col0, #T_9f7d5_row0_col1, #T_9f7d5_row0_col3, #T_9f7d5_row0_col4, #T_9f7d5_row0_col5, #T_9f7d5_row0_col7, #T_9f7d5_row0_col8, #T_9f7d5_row0_col12, #T_9f7d5_row0_col15, #T_9f7d5_row0_col16, #T_9f7d5_row1_col2, #T_9f7d5_row1_col6, #T_9f7d5_row1_col9, #T_9f7d5_row1_col10, #T_9f7d5_row1_col11, #T_9f7d5_row1_col13, #T_9f7d5_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_9f7d5_row0_col2, #T_9f7d5_row0_col6, #T_9f7d5_row0_col9, #T_9f7d5_row0_col10, #T_9f7d5_row0_col11, #T_9f7d5_row0_col13, #T_9f7d5_row0_col14, #T_9f7d5_row1_col0, #T_9f7d5_row1_col1, #T_9f7d5_row1_col3, #T_9f7d5_row1_col4, #T_9f7d5_row1_col5, #T_9f7d5_row1_col7, #T_9f7d5_row1_col8, #T_9f7d5_row1_col12, #T_9f7d5_row1_col15, #T_9f7d5_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9f7d5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
# ...

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()
